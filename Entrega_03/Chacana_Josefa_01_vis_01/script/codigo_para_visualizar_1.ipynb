# %%
pip install "altair[all]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import altair as alt
df = pd.read_csv("Datos_visualizacion.csv", sep = ";")
df.head(5)
# Out:
#                    Título en español Tipo de película  Año de estreno  \
# 0                      Pesos pesados      Imagen real            1995
# 1                   Man of the House      Imagen real            1995
# 2           La leyenda de Pecos Bill      Imagen real            1995
# 3  Goofy, la película / Goofy e hijo          Animada            1995
# 4                         Pocahontas          Animada            1995
#
#    Contenido
# 0  Original
# 1  Original
# 2  Original
# 3   Spin-Off
# 4  Original

# %%
import pandas as pd
import altair as alt

df = pd.read_csv("Datos_visualizacion.csv", sep=";")
alt.Chart(df).mark_arc(innerRadius=50).encode(
    theta="count()",
    color="Contenido:N",
).properties(
  title = "Contenido de las películas de Walt Disney Pictures desde 1995"
)
# Out:
# alt.Chart(...)
