# %%
import pandas as pd
url = "https://raw.githubusercontent.com/JosefaChacana/Repo_proyecto_disney/refs/heads/main/Entrega_02/La_Paz_Millaray_02_recaudaciones_02/Disney_presupuesto_recaudaci%C3%B3n_limpia.csv"
df = pd.read_csv(url, sep=';')
(df.head())
# Out:
#                                    Título en español  \
# 0  Blanca Nieves y los Siete Enanos / Blancanieve...
# 1                                            Pinocho
# 2                                           Fantasía
# 3                                 El dragón chiflado
# 4                                              Dumbo
#
#                    Título original  Fecha de estreno $ Inversión   \
# 0  Snow White and the Seven Dwarfs            1937.0      1490000
# 1                        Pinocchio            1940.0      2600000
# 2                         Fantasia            1940.0      2280000
# 3             The Reluctant Dragon            1941.0       600000
# 4                            Dumbo            1941.0       950000
#
#   $ Recaudación
# 0     5228953251
# 1     2188229052
# 2     2187090808
# 3            NaN
# 4        112,581
